# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ## Observations
#
# For Latitude vs. Temperature Plot, it shows that temperatures are at their highest nearest the equator.  Temperatures decrease the closer they get to the poles.
# For the Northern Hemisphere - Max Temp vs. Latitude Linear Regression there is a negative correlation.  As the latitude increases (moves farther away from the equator), the temperature decreases.
# For the Southern Hemisphere - Max Temp vs. Latitude Linear Regression, there is a positive correlation.  As latitude increases (moves closer to the equator), the temperature increases.
# For the Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression. there is no correlation.
# For the Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression. there is no correlation.

# %% [markdown]
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
from citipy import citipy
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
import scipy.stats as sts
from api_keys import weather_api_key
from pprint import pprint
import time
import os

# %% [markdown]
# ## Generate Cities List

# %%
curr_date = pd.to_datetime('today').date().strftime('%m/%d/%Y')

city_names = []
city_country_codes = []
city_count = 0


for i in range(2000):
    lat = np.random.uniform(-90, 90)
    lon = np.random.uniform(-180, 180)
    city = citipy.nearest_city(lat, lon)
    
    if city.city_name not in city_names:
        city_names.append(city.city_name)
        city_country_codes.append(city.country_code)
        
city_count=len(city_names)
print(city_count)
# Out:
# 782

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = 'http://api.openweathermap.org/data/2.5/weather?'

city_temps = []
city_lats = []
city_longs = []
city_hums = []
city_clouds = []
city_winds = []
cities_gathered = []
countries_gathered = []
city_dates = []
dash = '--------------------------'


n = 50
num = 10
city_name_list = [city_names[i * n:(i + 1) * n] for i in range((len(city_names) + n - 1) // n )]
city_country_codes_list = [city_country_codes[i * n:(i + 1) * n] for i in range((len(city_country_codes) + n - 1) // n )]

print(f'Beginning Retrieving Data')
print(dash)


for i in range(len(city_name_list)):
        time.sleep(num)
        for j in range(len(city_name_list[i])):
            one_city = city_name_list[i][j]
            one_country_code = city_country_codes_list[i][j]
            print(f'Processing record {j+1} of Group{i+1} | {one_city}, {one_country_code}')
            url = f'http://api.openweathermap.org/data/2.5/weather?q={one_city},{one_country_code}&units=imperial&appid={weather_api_key}'
            response = requests.get(url)
            if response.ok:
                response_json = response.json()
                cities_gathered.append(response_json['name'])
                city_lats.append(response_json['coord']['lat'])
                city_longs.append(response_json['coord']['lon'])
                city_temps.append(response_json['main']['temp_max'])
                city_hums.append(response_json['main']['humidity'])
                city_clouds.append(response_json['clouds']['all'])
                city_winds.append(response_json['wind']['speed'])     
                countries_gathered.append(response_json['sys']['country'])
                city_dates.append(response_json['dt']) 
            else:
                print('City not found. Skipping...')
      
        
print(dash)
print('Data Retrieval Complete')
print(dash)
# Out:
# Beginning Retrieving Data
# --------------------------
# Processing record 1 of Group1 | albany, au
# Processing record 2 of Group1 | ilulissat, gl
# Processing record 3 of Group1 | bogdanovich, ru
# Processing record 4 of Group1 | ushuaia, ar
# Processing record 5 of Group1 | tsihombe, mg
# City not found. Skipping...
# Processing record 6 of Group1 | chabahar, ir
# Processing record 7 of Group1 | barentsburg, sj
# City not found. Skipping...
# Processing record 8 of Group1 | talnakh, ru
# Processing record 9 of Group1 | arraial do cabo, br
# Processing record 10 of Group1 | richards bay, za
# Processing record 11 of Group1 | leticia, co
# Processing record 12 of Group1 | busselton, au
# Processing record 13 of Group1 | okhotsk, ru
# Processing record 14 of Group1 | biak, id
# Processing record 15 of Group1 | mataura, pf
# City not found. Skipping...
# Processing record 16 of Group1 | bambous virieux, mu
# Processing record 17 of Group1 | rikitea, pf
# Processing record 18 of Group1 | umm lajj, sa
# Processing record 19 of Group1 | cidreira, br
# Processing record 20 of Group1 | ancud, cl
# Processing record 21 of Group1 | avarua, ck
# Processing record 22 of Group1 | lavrentiya, ru
# Processing record 23 of Group1 | beloha, mg
# Processing record 24 of Group1 | moerai, pf
# Processing record 25 of Group1 | banyo, cm
# Processing record 26 of Group1 | sechura, pe
# Processing record 27 of Group1 | grindavik, is
# Processing record 28 of Group1 | pangnirtung, ca
# Processing record 29 of Group1 | cape town, za
# Processing record 30 of Group1 | kapaa, us
# Processing record 31 of Group1 | olafsvik, is
# Processing record 32 of Group1 | punta arenas, cl
# Processing record 33 of Group1 | thompson, ca
# Processing record 34 of Group1 | hithadhoo, mv
# Processing record 35 of Group1 | taksimo, ru
# Processing record 36 of Group1 | sampit, id
# Processing record 37 of Group1 | mount isa, au
# Processing record 38 of Group1 | kavieng, pg
# Processing record 39 of Group1 | cheuskiny, ru
# City not found. Skipping...
# Processing record 40 of Group1 | vila velha, br
# Processing record 41 of Group1 | kichera, ru
# Processing record 42 of Group1 | mar del plata, ar
# Processing record 43 of Group1 | pisco, pe
# Processing record 44 of Group1 | bengkulu, id
# Processing record 45 of Group1 | nikolskoye, ru
# Processing record 46 of Group1 | pauini, br
# Processing record 47 of Group1 | satitoa, ws
# City not found. Skipping...
# Processing record 48 of Group1 | grants, us
# Processing record 49 of Group1 | dwarka, in
# Processing record 50 of Group1 | rabo de peixe, pt
# Processing record 1 of Group2 | turtas, ru
# Processing record 2 of Group2 | attawapiskat, ca
# City not found. Skipping...
# Processing record 3 of Group2 | mount gambier, au
# Processing record 4 of Group2 | nuuk, gl
# Processing record 5 of Group2 | nizhneyansk, ru
# City not found. Skipping...
# Processing record 6 of Group2 | angoche, mz
# Processing record 7 of Group2 | georgetown, sh
# Processing record 8 of Group2 | bulawayo, zw
# Processing record 9 of Group2 | salalah, om
# Processing record 10 of Group2 | pacific grove, us
# Processing record 11 of Group2 | guerrero negro, mx
# Processing record 12 of Group2 | palmer, us
# Processing record 13 of Group2 | touros, br
# Processing record 14 of Group2 | humaita, br
# Processing record 15 of Group2 | dikson, ru
# Processing record 16 of Group2 | bredasdorp, za
# Processing record 17 of Group2 | lompoc, us
# Processing record 18 of Group2 | west plains, us
# Processing record 19 of Group2 | port lincoln, au
# Processing record 20 of Group2 | mahebourg, mu
# Processing record 21 of Group2 | klaksvik, fo
# Processing record 22 of Group2 | puerto ayora, ec
# Processing record 23 of Group2 | hokitika, nz
# Processing record 24 of Group2 | jamestown, sh
# Processing record 25 of Group2 | aklavik, ca
# Processing record 26 of Group2 | rognan, no
# Processing record 27 of Group2 | valka, lv
# Processing record 28 of Group2 | senanga, zm
# Processing record 29 of Group2 | chuy, uy
# Processing record 30 of Group2 | sola, vu
# Processing record 31 of Group2 | trelaze, fr
# Processing record 32 of Group2 | kyzyl-suu, kg
# Processing record 33 of Group2 | taolanaro, mg
# City not found. Skipping...
# Processing record 34 of Group2 | sterling, us
# Processing record 35 of Group2 | kota belud, my
# Processing record 36 of Group2 | coquimbo, cl
# Processing record 37 of Group2 | ajdabiya, ly
# Processing record 38 of Group2 | takoradi, gh
# Processing record 39 of Group2 | bac lieu, vn
# Processing record 40 of Group2 | broome, au
# Processing record 41 of Group2 | ambon, id
# Processing record 42 of Group2 | belushya guba, ru
# City not found. Skipping...
# Processing record 43 of Group2 | asau, tv
# City not found. Skipping...
# Processing record 44 of Group2 | saskylakh, ru
# Processing record 45 of Group2 | corpus christi, us
# Processing record 46 of Group2 | tshikapa, cd
# Processing record 47 of Group2 | hobart, au
# Processing record 48 of Group2 | zyryanka, ru
# Processing record 49 of Group2 | bluff, nz
# Processing record 50 of Group2 | virovitica, hr
# Processing record 1 of Group3 | dali, cn
# Processing record 2 of Group3 | palana, ru
# Processing record 3 of Group3 | vostok, ru
# Processing record 4 of Group3 | butaritari, ki
# Processing record 5 of Group3 | meaux, fr
# Processing record 6 of Group3 | seymchan, ru
# Processing record 7 of Group3 | komsomolskiy, ru
# Processing record 8 of Group3 | zhengjiatun, cn
# Processing record 9 of Group3 | lagoa, pt
# Processing record 10 of Group3 | banepa, np
# Processing record 11 of Group3 | jacareacanga, br
# Processing record 12 of Group3 | hilo, us
# Processing record 13 of Group3 | saint-augustin, ca
# Processing record 14 of Group3 | salinas, ec
# Processing record 15 of Group3 | millinocket, us
# Processing record 16 of Group3 | longyearbyen, sj
# Processing record 17 of Group3 | pimentel, pe
# Processing record 18 of Group3 | alice springs, au
# Processing record 19 of Group3 | karratha, au
# Processing record 20 of Group3 | sitka, us
# Processing record 21 of Group3 | tukrah, ly
# Processing record 22 of Group3 | constantine, dz
# Processing record 23 of Group3 | areia branca, br
# Processing record 24 of Group3 | faanui, pf
# Processing record 25 of Group3 | horsham, au
# Processing record 26 of Group3 | labuhan, id
# Processing record 27 of Group3 | namibe, ao
# Processing record 28 of Group3 | taoudenni, ml
# Processing record 29 of Group3 | castro, cl
# Processing record 30 of Group3 | yaan, cn
# City not found. Skipping...
# Processing record 31 of Group3 | ponta do sol, cv
# Processing record 32 of Group3 | new norfolk, au
# Processing record 33 of Group3 | illoqqortoormiut, gl
# City not found. Skipping...
# Processing record 34 of Group3 | tonantins, br
# Processing record 35 of Group3 | katsuura, jp
# Processing record 36 of Group3 | rodeo, mx
# Processing record 37 of Group3 | port hardy, ca
# Processing record 38 of Group3 | pevek, ru
# Processing record 39 of Group3 | paamiut, gl
# Processing record 40 of Group3 | samandag, tr
# Processing record 41 of Group3 | da lat, vn
# Processing record 42 of Group3 | bambanglipuro, id
# Processing record 43 of Group3 | rungata, ki
# City not found. Skipping...
# Processing record 44 of Group3 | bud, no
# Processing record 45 of Group3 | iskateley, ru
# Processing record 46 of Group3 | coahuayana, mx
# Processing record 47 of Group3 | borogontsy, ru
# Processing record 48 of Group3 | vattalkundu, in
# Processing record 49 of Group3 | de haan, be
# Processing record 50 of Group3 | bakchar, ru
# Processing record 1 of Group4 | saint-philippe, re
# Processing record 2 of Group4 | qaanaaq, gl
# Processing record 3 of Group4 | berlevag, no
# Processing record 4 of Group4 | east london, za
# Processing record 5 of Group4 | olinda, br
# Processing record 6 of Group4 | husavik, is
# Processing record 7 of Group4 | ust-kulom, ru
# Processing record 8 of Group4 | bethel, us
# Processing record 9 of Group4 | cherskiy, ru
# Processing record 10 of Group4 | marsh harbour, bs
# Processing record 11 of Group4 | lebu, cl
# Processing record 12 of Group4 | mezen, ru
# Processing record 13 of Group4 | acajutla, sv
# Processing record 14 of Group4 | muros, es
# Processing record 15 of Group4 | maumere, id
# Processing record 16 of Group4 | amderma, ru
# City not found. Skipping...
# Processing record 17 of Group4 | the valley, ai
# Processing record 18 of Group4 | vila do maio, cv
# Processing record 19 of Group4 | sisimiut, gl
# Processing record 20 of Group4 | khatanga, ru
# Processing record 21 of Group4 | matagami, ca
# Processing record 22 of Group4 | oussouye, sn
# Processing record 23 of Group4 | chokurdakh, ru
# Processing record 24 of Group4 | vanimo, pg
# Processing record 25 of Group4 | los llanos de aridane, es
# Processing record 26 of Group4 | karoi, zw
# Processing record 27 of Group4 | ellisras, za
# Processing record 28 of Group4 | mayo, ca
# Processing record 29 of Group4 | narsaq, gl
# Processing record 30 of Group4 | severo-kurilsk, ru
# Processing record 31 of Group4 | tarakan, id
# Processing record 32 of Group4 | lubango, ao
# Processing record 33 of Group4 | nikki, bj
# Processing record 34 of Group4 | jodhpur, in
# Processing record 35 of Group4 | saint-francois, gp
# Processing record 36 of Group4 | dingle, ie
# Processing record 37 of Group4 | oistins, bb
# Processing record 38 of Group4 | cayenne, gf
# Processing record 39 of Group4 | rundu, na
# Processing record 40 of Group4 | venezuela, cu
# Processing record 41 of Group4 | yagodnoye, ru
# Processing record 42 of Group4 | gorom-gorom, bf
# Processing record 43 of Group4 | thunder bay, ca
# Processing record 44 of Group4 | rosario oeste, br
# Processing record 45 of Group4 | acas, ro
# City not found. Skipping...
# Processing record 46 of Group4 | horki, by
# Processing record 47 of Group4 | yar-sale, ru
# Processing record 48 of Group4 | hukuntsi, bw
# Processing record 49 of Group4 | vaini, to
# Processing record 50 of Group4 | nova olimpia, br
# Processing record 1 of Group5 | torbay, ca
# Processing record 2 of Group5 | nome, us
# Processing record 3 of Group5 | jasdan, in
# Processing record 4 of Group5 | joao pinheiro, br
# Processing record 5 of Group5 | atuona, pf
# Processing record 6 of Group5 | napa, us
# Processing record 7 of Group5 | nova serrana, br
# Processing record 8 of Group5 | tasiilaq, gl
# Processing record 9 of Group5 | cabo san lucas, mx
# Processing record 10 of Group5 | yumen, cn
# Processing record 11 of Group5 | port alfred, za
# Processing record 12 of Group5 | inhambane, mz
# Processing record 13 of Group5 | kismayo, so
# Processing record 14 of Group5 | negele, et
# City not found. Skipping...
# Processing record 15 of Group5 | rabaul, pg
# Processing record 16 of Group5 | bend, us
# Processing record 17 of Group5 | grand river south east, mu
# City not found. Skipping...
# Processing record 18 of Group5 | barrow, us
# Processing record 19 of Group5 | kigorobya, ug
# Processing record 20 of Group5 | karnobat, bg
# Processing record 21 of Group5 | launceston, au
# Processing record 22 of Group5 | lerwick, gb
# Processing record 23 of Group5 | tura, ru
# Processing record 24 of Group5 | lolua, tv
# City not found. Skipping...
# Processing record 25 of Group5 | nioro, ml
# City not found. Skipping...
# Processing record 26 of Group5 | seoul, kr
# Processing record 27 of Group5 | yellowknife, ca
# Processing record 28 of Group5 | idlib, sy
# Processing record 29 of Group5 | maningrida, au
# Processing record 30 of Group5 | norman wells, ca
# Processing record 31 of Group5 | hun, ly
# Processing record 32 of Group5 | mnogovershinnyy, ru
# Processing record 33 of Group5 | ornskoldsvik, se
# Processing record 34 of Group5 | saint george, bm
# Processing record 35 of Group5 | rawson, ar
# Processing record 36 of Group5 | sinnamary, gf
# Processing record 37 of Group5 | itoman, jp
# Processing record 38 of Group5 | vaitupu, wf
# City not found. Skipping...
# Processing record 39 of Group5 | saldanha, za
# Processing record 40 of Group5 | san cristobal, ec
# Processing record 41 of Group5 | portland, au
# Processing record 42 of Group5 | vestmannaeyjar, is
# Processing record 43 of Group5 | lakhnadon, in
# Processing record 44 of Group5 | qasigiannguit, gl
# Processing record 45 of Group5 | magadi, ke
# Processing record 46 of Group5 | upernavik, gl
# Processing record 47 of Group5 | naze, jp
# Processing record 48 of Group5 | liku, wf
# City not found. Skipping...
# Processing record 49 of Group5 | tessalit, ml
# Processing record 50 of Group5 | bjala, bg
# City not found. Skipping...
# Processing record 1 of Group6 | ribeira grande, pt
# Processing record 2 of Group6 | da nang, vn
# Processing record 3 of Group6 | moron, mn
# Processing record 4 of Group6 | christchurch, nz
# Processing record 5 of Group6 | bilibino, ru
# Processing record 6 of Group6 | dudinka, ru
# Processing record 7 of Group6 | banda aceh, id
# Processing record 8 of Group6 | kruisfontein, za
# Processing record 9 of Group6 | carnarvon, au
# Processing record 10 of Group6 | hermanus, za
# Processing record 11 of Group6 | samalaeulu, ws
# City not found. Skipping...
# Processing record 12 of Group6 | harper, lr
# Processing record 13 of Group6 | sao joao da barra, br
# Processing record 14 of Group6 | krasnoselkup, ru
# Processing record 15 of Group6 | ak-dovurak, ru
# Processing record 16 of Group6 | cairns, au
# Processing record 17 of Group6 | ambulu, id
# Processing record 18 of Group6 | jiwani, pk
# Processing record 19 of Group6 | bonito, br
# Processing record 20 of Group6 | te anau, nz
# Processing record 21 of Group6 | moi, no
# Processing record 22 of Group6 | kaitangata, nz
# Processing record 23 of Group6 | kodiak, us
# Processing record 24 of Group6 | thinadhoo, mv
# Processing record 25 of Group6 | hofn, is
# Processing record 26 of Group6 | vysokogornyy, ru
# Processing record 27 of Group6 | souillac, mu
# Processing record 28 of Group6 | wahran, dz
# City not found. Skipping...
# Processing record 29 of Group6 | bideford, gb
# Processing record 30 of Group6 | ca mau, vn
# Processing record 31 of Group6 | toliary, mg
# City not found. Skipping...
# Processing record 32 of Group6 | esmeraldas, ec
# Processing record 33 of Group6 | kieta, pg
# Processing record 34 of Group6 | warrnambool, au
# Processing record 35 of Group6 | havoysund, no
# Processing record 36 of Group6 | malm, no
# Processing record 37 of Group6 | nampula, mz
# Processing record 38 of Group6 | aksarka, ru
# Processing record 39 of Group6 | aranos, na
# Processing record 40 of Group6 | blythe, us
# Processing record 41 of Group6 | morondava, mg
# Processing record 42 of Group6 | rock sound, bs
# Processing record 43 of Group6 | taltal, cl
# Processing record 44 of Group6 | santiago del estero, ar
# Processing record 45 of Group6 | comodoro rivadavia, ar
# Processing record 46 of Group6 | matay, eg
# Processing record 47 of Group6 | ostersund, se
# Processing record 48 of Group6 | rongcheng, cn
# Processing record 49 of Group6 | lorengau, pg
# Processing record 50 of Group6 | macaboboni, ph
# City not found. Skipping...
# Processing record 1 of Group7 | sitio novo do tocantins, br
# Processing record 2 of Group7 | provideniya, ru
# Processing record 3 of Group7 | fairbanks, us
# Processing record 4 of Group7 | galiwinku, au
# City not found. Skipping...
# Processing record 5 of Group7 | terre haute, us
# Processing record 6 of Group7 | poltavka, ru
# Processing record 7 of Group7 | esperance, au
# Processing record 8 of Group7 | jujuy, ar
# City not found. Skipping...
# Processing record 9 of Group7 | atambua, id
# Processing record 10 of Group7 | tiksi, ru
# Processing record 11 of Group7 | aguimes, es
# Processing record 12 of Group7 | broken hill, au
# Processing record 13 of Group7 | ponazyrevo, ru
# Processing record 14 of Group7 | tuxtla chico, mx
# Processing record 15 of Group7 | kaka, tm
# Processing record 16 of Group7 | folldal, no
# Processing record 17 of Group7 | kerema, pg
# Processing record 18 of Group7 | barabai, id
# Processing record 19 of Group7 | kambove, cd
# Processing record 20 of Group7 | puerto del rosario, es
# Processing record 21 of Group7 | salta, ar
# Processing record 22 of Group7 | noshiro, jp
# Processing record 23 of Group7 | soyo, ao
# Processing record 24 of Group7 | kharp, ru
# Processing record 25 of Group7 | gizo, sb
# Processing record 26 of Group7 | koutiala, ml
# Processing record 27 of Group7 | tumannyy, ru
# City not found. Skipping...
# Processing record 28 of Group7 | coihaique, cl
# Processing record 29 of Group7 | belaya gora, ru
# Processing record 30 of Group7 | srednekolymsk, ru
# Processing record 31 of Group7 | bhakkar, pk
# Processing record 32 of Group7 | lucea, jm
# Processing record 33 of Group7 | songjianghe, cn
# Processing record 34 of Group7 | half moon bay, us
# Processing record 35 of Group7 | hervey bay, au
# Processing record 36 of Group7 | ust-kuyga, ru
# Processing record 37 of Group7 | rafsanjan, ir
# Processing record 38 of Group7 | tianpeng, cn
# Processing record 39 of Group7 | westport, nz
# Processing record 40 of Group7 | tawang, in
# Processing record 41 of Group7 | airai, pw
# City not found. Skipping...
# Processing record 42 of Group7 | nadadores, mx
# Processing record 43 of Group7 | sao jose da coroa grande, br
# Processing record 44 of Group7 | mildura, au
# Processing record 45 of Group7 | kasongo-lunda, cd
# Processing record 46 of Group7 | port macquarie, au
# Processing record 47 of Group7 | mys shmidta, ru
# City not found. Skipping...
# Processing record 48 of Group7 | emerald, au
# Processing record 49 of Group7 | ondorhaan, mn
# City not found. Skipping...
# Processing record 50 of Group7 | asfi, ma
# Processing record 1 of Group8 | sentyabrskiy, ru
# City not found. Skipping...
# Processing record 2 of Group8 | victoria, sc
# Processing record 3 of Group8 | caravelas, br
# Processing record 4 of Group8 | acapulco, mx
# Processing record 5 of Group8 | nambucca heads, au
# Processing record 6 of Group8 | necochea, ar
# Processing record 7 of Group8 | basoko, cd
# Processing record 8 of Group8 | bandarbeyla, so
# Processing record 9 of Group8 | minab, ir
# Processing record 10 of Group8 | barcelos, br
# Processing record 11 of Group8 | bushehr, ir
# Processing record 12 of Group8 | winnemucca, us
# Processing record 13 of Group8 | luderitz, na
# Processing record 14 of Group8 | palafrugell, es
# Processing record 15 of Group8 | kazalinsk, kz
# City not found. Skipping...
# Processing record 16 of Group8 | alexandroupoli, gr
# Processing record 17 of Group8 | oranjemund, na
# Processing record 18 of Group8 | bais, ph
# Processing record 19 of Group8 | gat, ly
# City not found. Skipping...
# Processing record 20 of Group8 | belmonte, br
# Processing record 21 of Group8 | aporawan, ph
# City not found. Skipping...
# Processing record 22 of Group8 | timberlake, us
# Processing record 23 of Group8 | eyl, so
# Processing record 24 of Group8 | dalby, au
# Processing record 25 of Group8 | bequimao, br
# Processing record 26 of Group8 | upata, ve
# Processing record 27 of Group8 | hami, cn
# Processing record 28 of Group8 | mormugao, in
# Processing record 29 of Group8 | tuatapere, nz
# Processing record 30 of Group8 | prince rupert, ca
# Processing record 31 of Group8 | terra boa, br
# Processing record 32 of Group8 | sembe, cg
# Processing record 33 of Group8 | bykovo, ru
# Processing record 34 of Group8 | fare, pf
# Processing record 35 of Group8 | erenhot, cn
# Processing record 36 of Group8 | huilong, cn
# Processing record 37 of Group8 | ust-ilimsk, ru
# Processing record 38 of Group8 | kimbe, pg
# Processing record 39 of Group8 | yulara, au
# Processing record 40 of Group8 | rio cuarto, ar
# Processing record 41 of Group8 | dunedin, nz
# Processing record 42 of Group8 | marcali, hu
# Processing record 43 of Group8 | lalibela, et
# Processing record 44 of Group8 | port elizabeth, za
# Processing record 45 of Group8 | tupelo, us
# Processing record 46 of Group8 | warqla, dz
# City not found. Skipping...
# Processing record 47 of Group8 | kutum, sd
# Processing record 48 of Group8 | maracas, br
# Processing record 49 of Group8 | genhe, cn
# Processing record 50 of Group8 | ayan, ru
# Processing record 1 of Group9 | sakakah, sa
# Processing record 2 of Group9 | pochutla, mx
# Processing record 3 of Group9 | yanchukan, ru
# City not found. Skipping...
# Processing record 4 of Group9 | vuktyl, ru
# Processing record 5 of Group9 | tuktoyaktuk, ca
# Processing record 6 of Group9 | weihe, cn
# Processing record 7 of Group9 | tabas, ir
# Processing record 8 of Group9 | enumclaw, us
# Processing record 9 of Group9 | caucaia, br
# Processing record 10 of Group9 | bogande, bf
# Processing record 11 of Group9 | mehamn, no
# Processing record 12 of Group9 | geraldton, au
# Processing record 13 of Group9 | ossora, ru
# Processing record 14 of Group9 | laguna, br
# Processing record 15 of Group9 | waipawa, nz
# Processing record 16 of Group9 | san luis, mx
# Processing record 17 of Group9 | hambantota, lk
# Processing record 18 of Group9 | marcona, pe
# City not found. Skipping...
# Processing record 19 of Group9 | arman, ru
# Processing record 20 of Group9 | karakose, tr
# City not found. Skipping...
# Processing record 21 of Group9 | ahipara, nz
# Processing record 22 of Group9 | ulaangom, mn
# Processing record 23 of Group9 | zaozerne, ua
# Processing record 24 of Group9 | miri, my
# Processing record 25 of Group9 | opportunity, us
# Processing record 26 of Group9 | noumea, nc
# Processing record 27 of Group9 | voh, nc
# Processing record 28 of Group9 | huarmey, pe
# Processing record 29 of Group9 | bathsheba, bb
# Processing record 30 of Group9 | fortuna, us
# Processing record 31 of Group9 | grand gaube, mu
# Processing record 32 of Group9 | griffith, au
# Processing record 33 of Group9 | rincon, an
# City not found. Skipping...
# Processing record 34 of Group9 | kyzyl-mazhalyk, ru
# Processing record 35 of Group9 | clyde river, ca
# Processing record 36 of Group9 | nazilli, tr
# Processing record 37 of Group9 | la palma, pa
# Processing record 38 of Group9 | butte, us
# Processing record 39 of Group9 | tommot, ru
# Processing record 40 of Group9 | camacha, pt
# Processing record 41 of Group9 | lasa, cn
# City not found. Skipping...
# Processing record 42 of Group9 | luis correia, br
# Processing record 43 of Group9 | kavaratti, in
# Processing record 44 of Group9 | mana, gf
# Processing record 45 of Group9 | madimba, tz
# Processing record 46 of Group9 | lazaro cardenas, mx
# Processing record 47 of Group9 | slavgorodskoye, ru
# Processing record 48 of Group9 | odweyne, so
# Processing record 49 of Group9 | hermon, us
# Processing record 50 of Group9 | dipalpur, pk
# Processing record 1 of Group10 | hell, no
# Processing record 2 of Group10 | ayorou, ne
# Processing record 3 of Group10 | saleaula, ws
# City not found. Skipping...
# Processing record 4 of Group10 | yeppoon, au
# Processing record 5 of Group10 | bagacay, ph
# Processing record 6 of Group10 | bereda, so
# City not found. Skipping...
# Processing record 7 of Group10 | tambura, sd
# City not found. Skipping...
# Processing record 8 of Group10 | quelimane, mz
# Processing record 9 of Group10 | babu, cn
# Processing record 10 of Group10 | arlit, ne
# Processing record 11 of Group10 | besigheim, de
# Processing record 12 of Group10 | fort morgan, us
# Processing record 13 of Group10 | isla vista, us
# Processing record 14 of Group10 | nortelandia, br
# Processing record 15 of Group10 | camopi, gf
# Processing record 16 of Group10 | kamina, cd
# Processing record 17 of Group10 | amarante, br
# Processing record 18 of Group10 | nanortalik, gl
# Processing record 19 of Group10 | uyuni, bo
# Processing record 20 of Group10 | kalabo, zm
# Processing record 21 of Group10 | charters towers, au
# Processing record 22 of Group10 | harlingen, nl
# Processing record 23 of Group10 | nizwa, om
# Processing record 24 of Group10 | umzimvubu, za
# City not found. Skipping...
# Processing record 25 of Group10 | honningsvag, no
# Processing record 26 of Group10 | auki, sb
# Processing record 27 of Group10 | hasaki, jp
# Processing record 28 of Group10 | qiyang, cn
# Processing record 29 of Group10 | kawalu, id
# Processing record 30 of Group10 | stornoway, gb
# Processing record 31 of Group10 | dzaoudzi, yt
# Processing record 32 of Group10 | homer, us
# Processing record 33 of Group10 | dolores, ar
# Processing record 34 of Group10 | krasnoznamensk, ru
# Processing record 35 of Group10 | kuryk, kz
# Processing record 36 of Group10 | beringovskiy, ru
# Processing record 37 of Group10 | golden, ca
# Processing record 38 of Group10 | san joaquin, bo
# Processing record 39 of Group10 | jacksonville, us
# Processing record 40 of Group10 | awjilah, ly
# Processing record 41 of Group10 | puerto colombia, co
# Processing record 42 of Group10 | vardo, no
# Processing record 43 of Group10 | aitape, pg
# Processing record 44 of Group10 | svetlyy, ru
# Processing record 45 of Group10 | eyrarbakki, is
# Processing record 46 of Group10 | tebingtinggi, id
# Processing record 47 of Group10 | termoli, it
# Processing record 48 of Group10 | mrirt, ma
# City not found. Skipping...
# Processing record 49 of Group10 | eureka, us
# Processing record 50 of Group10 | bubaque, gw
# Processing record 1 of Group11 | makakilo city, us
# Processing record 2 of Group11 | plyussa, ru
# Processing record 3 of Group11 | maghama, mr
# City not found. Skipping...
# Processing record 4 of Group11 | meshcherino, ru
# Processing record 5 of Group11 | tateyama, jp
# Processing record 6 of Group11 | ust-barguzin, ru
# Processing record 7 of Group11 | maldonado, uy
# Processing record 8 of Group11 | farafangana, mg
# Processing record 9 of Group11 | pasni, pk
# Processing record 10 of Group11 | juifang, tw
# City not found. Skipping...
# Processing record 11 of Group11 | viedma, ar
# Processing record 12 of Group11 | matamoros, mx
# Processing record 13 of Group11 | asyut, eg
# Processing record 14 of Group11 | axim, gh
# Processing record 15 of Group11 | gogrial, sd
# City not found. Skipping...
# Processing record 16 of Group11 | kloulklubed, pw
# Processing record 17 of Group11 | jijiga, et
# Processing record 18 of Group11 | sibolga, id
# Processing record 19 of Group11 | waynesboro, us
# Processing record 20 of Group11 | along, in
# Processing record 21 of Group11 | kudahuvadhoo, mv
# Processing record 22 of Group11 | mugango, tz
# Processing record 23 of Group11 | quatre cocos, mu
# Processing record 24 of Group11 | natal, br
# Processing record 25 of Group11 | buraydah, sa
# Processing record 26 of Group11 | hualmay, pe
# Processing record 27 of Group11 | dzhusaly, kz
# City not found. Skipping...
# Processing record 28 of Group11 | urucui, br
# Processing record 29 of Group11 | manta, ec
# Processing record 30 of Group11 | ulladulla, au
# Processing record 31 of Group11 | sarny, ua
# Processing record 32 of Group11 | haldibari, in
# Processing record 33 of Group11 | antofagasta, cl
# Processing record 34 of Group11 | mpika, zm
# Processing record 35 of Group11 | jinchengjiang, cn
# City not found. Skipping...
# Processing record 36 of Group11 | susehri, tr
# Processing record 37 of Group11 | palm desert, us
# Processing record 38 of Group11 | carballo, es
# Processing record 39 of Group11 | mudyuga, ru
# City not found. Skipping...
# Processing record 40 of Group11 | carutapera, br
# Processing record 41 of Group11 | skalistyy, ru
# City not found. Skipping...
# Processing record 42 of Group11 | ikalamavony, mg
# Processing record 43 of Group11 | novyy buh, ua
# Processing record 44 of Group11 | saint-louis, re
# Processing record 45 of Group11 | andenes, no
# Processing record 46 of Group11 | victor harbor, au
# Processing record 47 of Group11 | ust-kishert, ru
# Processing record 48 of Group11 | presidencia roque saenz pena, ar
# Processing record 49 of Group11 | leningradskiy, ru
# Processing record 50 of Group11 | sao miguel do oeste, br
# City not found. Skipping...
# Processing record 1 of Group12 | el cope, pa
# Processing record 2 of Group12 | brownfield, us
# Processing record 3 of Group12 | jefferson city, us
# Processing record 4 of Group12 | brownwood, us
# Processing record 5 of Group12 | karamea, nz
# City not found. Skipping...
# Processing record 6 of Group12 | marshalltown, us
# Processing record 7 of Group12 | praia da vitoria, pt
# Processing record 8 of Group12 | baykit, ru
# Processing record 9 of Group12 | svencioneliai, lt
# Processing record 10 of Group12 | cap malheureux, mu
# Processing record 11 of Group12 | nhulunbuy, au
# Processing record 12 of Group12 | kununurra, au
# Processing record 13 of Group12 | mussomeli, it
# Processing record 14 of Group12 | moose factory, ca
# Processing record 15 of Group12 | kugulta, ru
# Processing record 16 of Group12 | acari, pe
# Processing record 17 of Group12 | ati, td
# Processing record 18 of Group12 | samusu, ws
# City not found. Skipping...
# Processing record 19 of Group12 | bang saphan, th
# Processing record 20 of Group12 | sidi qasim, ma
# City not found. Skipping...
# Processing record 21 of Group12 | tezpur, in
# Processing record 22 of Group12 | meulaboh, id
# Processing record 23 of Group12 | wukari, ng
# Processing record 24 of Group12 | nichinan, jp
# Processing record 25 of Group12 | alberton, ca
# Processing record 26 of Group12 | simao, cn
# Processing record 27 of Group12 | soe, id
# Processing record 28 of Group12 | waingapu, id
# Processing record 29 of Group12 | bonavista, ca
# Processing record 30 of Group12 | baran, in
# Processing record 31 of Group12 | narasannapeta, in
# Processing record 32 of Group12 | mogok, mm
# Processing record 33 of Group12 | aguada de cima, pt
# Processing record 34 of Group12 | tabiauea, ki
# City not found. Skipping...
# Processing record 35 of Group12 | vagur, fo
# Processing record 36 of Group12 | bani walid, ly
# Processing record 37 of Group12 | pelym, ru
# Processing record 38 of Group12 | langham, ca
# Processing record 39 of Group12 | luanda, ao
# Processing record 40 of Group12 | terme, tr
# Processing record 41 of Group12 | koumac, nc
# Processing record 42 of Group12 | iqaluit, ca
# Processing record 43 of Group12 | laurinburg, us
# Processing record 44 of Group12 | vrangel, ru
# Processing record 45 of Group12 | viking, ca
# Processing record 46 of Group12 | ust-maya, ru
# Processing record 47 of Group12 | chapais, ca
# Processing record 48 of Group12 | umm durman, sd
# City not found. Skipping...
# Processing record 49 of Group12 | las lomas, pe
# Processing record 50 of Group12 | bairnsdale, au
# Processing record 1 of Group13 | pudozh, ru
# Processing record 2 of Group13 | dingzhou, cn
# Processing record 3 of Group13 | dilla, et
# Processing record 4 of Group13 | smithers, ca
# Processing record 5 of Group13 | lucapa, ao
# Processing record 6 of Group13 | den helder, nl
# Processing record 7 of Group13 | ulaanbaatar, mn
# Processing record 8 of Group13 | glazov, ru
# Processing record 9 of Group13 | san onofre, co
# Processing record 10 of Group13 | dhidhdhoo, mv
# Processing record 11 of Group13 | kinanah, sd
# City not found. Skipping...
# Processing record 12 of Group13 | rio gallegos, ar
# Processing record 13 of Group13 | bolungarvik, is
# City not found. Skipping...
# Processing record 14 of Group13 | piranshahr, ir
# Processing record 15 of Group13 | kargasok, ru
# Processing record 16 of Group13 | bien hoa, vn
# Processing record 17 of Group13 | san patricio, mx
# Processing record 18 of Group13 | ouesso, cg
# Processing record 19 of Group13 | outlook, ca
# Processing record 20 of Group13 | suileng, cn
# Processing record 21 of Group13 | alta floresta, br
# Processing record 22 of Group13 | hefei, cn
# Processing record 23 of Group13 | saint-ambroise, ca
# Processing record 24 of Group13 | korla, cn
# Processing record 25 of Group13 | galdar, es
# Processing record 26 of Group13 | sabang, id
# Processing record 27 of Group13 | sao gabriel da cachoeira, br
# Processing record 28 of Group13 | garissa, ke
# Processing record 29 of Group13 | cauquenes, cl
# Processing record 30 of Group13 | tawkar, sd
# City not found. Skipping...
# Processing record 31 of Group13 | armstrong, ca
# Processing record 32 of Group13 | vao, nc
# Processing record 33 of Group13 | anadyr, ru
# Processing record 34 of Group13 | chicama, pe
# Processing record 35 of Group13 | zhaozhou, cn
# Processing record 36 of Group13 | duvan, ru
# Processing record 37 of Group13 | mendi, pg
# Processing record 38 of Group13 | shieli, kz
# Processing record 39 of Group13 | skelleftea, se
# Processing record 40 of Group13 | lahaina, us
# Processing record 41 of Group13 | mengcheng, cn
# Processing record 42 of Group13 | cravo norte, co
# Processing record 43 of Group13 | port augusta, au
# Processing record 44 of Group13 | agadir, ma
# Processing record 45 of Group13 | toora-khem, ru
# Processing record 46 of Group13 | marystown, ca
# Processing record 47 of Group13 | camacupa, ao
# Processing record 48 of Group13 | fukue, jp
# Processing record 49 of Group13 | narimanov, ru
# Processing record 50 of Group13 | cooma, au
# Processing record 1 of Group14 | le moule, gp
# Processing record 2 of Group14 | fengzhen, cn
# Processing record 3 of Group14 | lahat, id
# Processing record 4 of Group14 | novonikolayevskiy, ru
# Processing record 5 of Group14 | ximei, cn
# Processing record 6 of Group14 | port keats, au
# Processing record 7 of Group14 | zhigansk, ru
# Processing record 8 of Group14 | meyungs, pw
# City not found. Skipping...
# Processing record 9 of Group14 | tokur, ru
# Processing record 10 of Group14 | tiko, cm
# Processing record 11 of Group14 | we, nc
# Processing record 12 of Group14 | qaqortoq, gl
# Processing record 13 of Group14 | poya, nc
# Processing record 14 of Group14 | pingliang, cn
# Processing record 15 of Group14 | koslan, ru
# Processing record 16 of Group14 | aasiaat, gl
# Processing record 17 of Group14 | karkaralinsk, kz
# City not found. Skipping...
# Processing record 18 of Group14 | marzuq, ly
# City not found. Skipping...
# Processing record 19 of Group14 | dnipryany, ua
# Processing record 20 of Group14 | pogana, ro
# Processing record 21 of Group14 | dzhuryn, ua
# Processing record 22 of Group14 | bonaberi, cm
# Processing record 23 of Group14 | vila franca do campo, pt
# Processing record 24 of Group14 | ust-omchug, ru
# Processing record 25 of Group14 | yichun, cn
# Processing record 26 of Group14 | balkanabat, tm
# Processing record 27 of Group14 | doha, kw
# City not found. Skipping...
# Processing record 28 of Group14 | namatanai, pg
# Processing record 29 of Group14 | trincomalee, lk
# Processing record 30 of Group14 | dharchula, in
# Processing record 31 of Group14 | wembley, ca
# Processing record 32 of Group14 | north bend, us
# Processing record 33 of Group14 | nuoro, it
# Processing record 34 of Group14 | praya, id
# Processing record 35 of Group14 | navalmoral de la mata, es
# Processing record 36 of Group14 | khorixas, na
# Processing record 37 of Group14 | yichang, cn
# Processing record 38 of Group14 | kolondieba, ml
# Processing record 39 of Group14 | sioux lookout, ca
# Processing record 40 of Group14 | karaul, ru
# City not found. Skipping...
# Processing record 41 of Group14 | kerteminde, dk
# Processing record 42 of Group14 | whitehorse, ca
# Processing record 43 of Group14 | bilma, ne
# Processing record 44 of Group14 | khash, ir
# Processing record 45 of Group14 | kegayli, uz
# City not found. Skipping...
# Processing record 46 of Group14 | merritt island, us
# Processing record 47 of Group14 | margate, za
# Processing record 48 of Group14 | stamsund, no
# City not found. Skipping...
# Processing record 49 of Group14 | panaba, mx
# Processing record 50 of Group14 | shemordan, ru
# Processing record 1 of Group15 | brae, gb
# Processing record 2 of Group15 | palabuhanratu, id
# City not found. Skipping...
# Processing record 3 of Group15 | susanville, us
# Processing record 4 of Group15 | mahaicony, gy
# City not found. Skipping...
# Processing record 5 of Group15 | bundaberg, au
# Processing record 6 of Group15 | aksu, kz
# Processing record 7 of Group15 | halalo, wf
# City not found. Skipping...
# Processing record 8 of Group15 | louisbourg, ca
# City not found. Skipping...
# Processing record 9 of Group15 | bay roberts, ca
# Processing record 10 of Group15 | paita, pe
# Processing record 11 of Group15 | millau, fr
# Processing record 12 of Group15 | bargal, so
# City not found. Skipping...
# Processing record 13 of Group15 | slave lake, ca
# Processing record 14 of Group15 | kitale, ke
# Processing record 15 of Group15 | artyk, ru
# City not found. Skipping...
# Processing record 16 of Group15 | khandyga, ru
# Processing record 17 of Group15 | shache, cn
# Processing record 18 of Group15 | jiayuguan, cn
# Processing record 19 of Group15 | horta, pt
# Processing record 20 of Group15 | svirsk, ru
# Processing record 21 of Group15 | morbach, de
# Processing record 22 of Group15 | yomitan, jp
# City not found. Skipping...
# Processing record 23 of Group15 | tuggurt, dz
# City not found. Skipping...
# Processing record 24 of Group15 | north myrtle beach, us
# Processing record 25 of Group15 | mindelo, cv
# Processing record 26 of Group15 | kirakira, sb
# Processing record 27 of Group15 | ketchikan, us
# Processing record 28 of Group15 | indianola, us
# Processing record 29 of Group15 | khani, ru
# City not found. Skipping...
# Processing record 30 of Group15 | yambio, sd
# City not found. Skipping...
# Processing record 31 of Group15 | bhuj, in
# Processing record 32 of Group15 | kinablangan, ph
# Processing record 33 of Group15 | utiroa, ki
# City not found. Skipping...
# Processing record 34 of Group15 | sur, om
# Processing record 35 of Group15 | poum, nc
# Processing record 36 of Group15 | chimoio, mz
# Processing record 37 of Group15 | lae, pg
# Processing record 38 of Group15 | pitimbu, br
# Processing record 39 of Group15 | kahului, us
# Processing record 40 of Group15 | isangel, vu
# Processing record 41 of Group15 | najran, sa
# Processing record 42 of Group15 | helvecia, hu
# Processing record 43 of Group15 | santa cruz de la palma, es
# Processing record 44 of Group15 | nishihara, jp
# Processing record 45 of Group15 | niono, ml
# Processing record 46 of Group15 | ewa beach, us
# Processing record 47 of Group15 | marsa matruh, eg
# Processing record 48 of Group15 | melekhovskaya, ru
# City not found. Skipping...
# Processing record 49 of Group15 | tromso, no
# Processing record 50 of Group15 | ishigaki, jp
# Processing record 1 of Group16 | balan, ro
# Processing record 2 of Group16 | flinders, au
# Processing record 3 of Group16 | guadalupe y calvo, mx
# Processing record 4 of Group16 | valer, no
# Processing record 5 of Group16 | avera, pf
# City not found. Skipping...
# Processing record 6 of Group16 | digby, ca
# Processing record 7 of Group16 | yangjiang, cn
# Processing record 8 of Group16 | killini, gr
# City not found. Skipping...
# Processing record 9 of Group16 | tautira, pf
# Processing record 10 of Group16 | chara, ru
# Processing record 11 of Group16 | caranavi, bo
# Processing record 12 of Group16 | ustka, pl
# Processing record 13 of Group16 | tubruq, ly
# City not found. Skipping...
# Processing record 14 of Group16 | haimen, cn
# Processing record 15 of Group16 | port hawkesbury, ca
# Processing record 16 of Group16 | sikasso, ml
# Processing record 17 of Group16 | raghunathpur, in
# Processing record 18 of Group16 | mafinga, tz
# Processing record 19 of Group16 | killybegs, ie
# Processing record 20 of Group16 | mentok, id
# City not found. Skipping...
# Processing record 21 of Group16 | pemangkat, id
# Processing record 22 of Group16 | nakambala, zm
# Processing record 23 of Group16 | nieuw nickerie, sr
# Processing record 24 of Group16 | krasnorechenskiy, ru
# Processing record 25 of Group16 | high prairie, ca
# Processing record 26 of Group16 | nemuro, jp
# Processing record 27 of Group16 | andilamena, mg
# Processing record 28 of Group16 | bhindar, in
# Processing record 29 of Group16 | cabedelo, br
# Processing record 30 of Group16 | abu samrah, qa
# City not found. Skipping...
# Processing record 31 of Group16 | sambava, mg
# Processing record 32 of Group16 | ouadda, cf
# --------------------------
# Data Retrieval Complete
# --------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_dict = {
    'City': cities_gathered,  
    'Lat': city_lats,
    'Lng': city_longs,
    'Max Temp': city_temps,
    'Humidity': city_hums,
    'Cloudiness': city_clouds,
    'Wind Speed': city_winds,
    'Country': countries_gathered,
    'Date': city_dates
    }
city_weather_data = pd.DataFrame(city_weather_dict)
city_weather_data
out_file = os.path.join('..', '..', 'Resources', 'city_weather_data.csv')
city_weather_data.to_csv(out_file, index=False)

# %%
html = city_weather_data.to_html() 

out_file = os.path.join('..', '..', 'Resources', "city_weather_data.html")
  
# write html to file 
text_file = open(out_file, "w", encoding="utf-8")
text_file.write(html) 
text_file.close()

# %%
city_weather_data_describe = city_weather_data.describe()
city_weather_data_describe
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  695.000000  695.000000  695.000000  695.000000  695.000000  695.000000
# mean    19.308144   22.454058   60.807496   72.211511   52.450360    8.063468
# std     33.283175   89.628789   20.680804   21.468693   38.854121    5.547798
# min    -54.800000 -175.200000    6.660000    1.000000    0.000000    0.380000
# 25%     -8.225000  -56.290000   44.670000   64.000000    9.500000    4.050000
# 50%     23.270000   25.810000   66.200000   78.000000   55.000000    6.930000
# 75%     47.695000  103.430000   77.445000   88.000000   90.000000   10.930000
# max     78.220000  179.320000  103.390000  100.000000  100.000000   36.860000
#
#                Date
# count  6.950000e+02
# mean   1.603055e+09
# std    1.548330e+02
# min    1.603054e+09
# 25%    1.603055e+09
# 50%    1.603055e+09
# 75%    1.603055e+09
# max    1.603055e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
cd_greater_humidity = city_weather_data.loc[city_weather_data['Humidity'] > 100]

print(f'City weather data length is {len(city_weather_data)}')
print(f'Greater humidity length is {len(cd_greater_humidity)}')
cd_greater_humidity
# Out:
# City weather data length is 695
# Greater humidity length is 0
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_weather_data.drop(cd_greater_humidity.index, inplace=False)

print(f'Total records in clean_city_data dataframe is {len(clean_city_data)}')
clean_city_data
# Out:
# Total records in clean_city_data dataframe is 695
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Albany -35.02  117.89     55.40        87          14        6.93
# 1      Ilulissat  69.22  -51.10     42.80        45         100       17.22
# 2    Bogdanovich  56.78   62.05     37.76        76         100       16.91
# 3        Ushuaia -54.80  -68.30     41.00        80          75       29.97
# 4       Chabahar  25.29   60.64     77.70        27           0       12.08
# ..           ...    ...     ...       ...       ...         ...         ...
# 690   Andilamena -17.02   48.58     59.52        93          20        5.95
# 691      Bhindār  24.50   74.18     75.72        81          84        5.93
# 692     Cabedelo  -6.98  -34.83     80.60        69          20       12.75
# 693      Sambava -14.27   50.17     71.08        82           5       10.63
# 694       Ouadda   8.08   22.40     70.00        86          60        2.84
#
#     Country        Date
# 0        AU  1603054832
# 1        GL  1603054791
# 2        RU  1603054832
# 3        AR  1603054362
# 4        IR  1603054833
# ..      ...         ...
# 690      MG  1603055114
# 691      IN  1603055114
# 692      BR  1603054997
# 693      MG  1603055025
# 694      CF  1603055115
#
# [695 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# #create bin
# ages_bin = [0, 9, 14, 19, 24, 29, 34, 39, 100]

# #create lables
# ages_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]


#create bin
lats_bin = [-79, -59, -39, -19, 0, 19, 39, 59, 100]

#create lables
lats_labels = ["-60+", "-40-59", "-20-39", "-19--1", "0-19", "20-39", "40-59", "60+"]


# #create bin
# cat_bin = [0, 19, 39, 59, 79, 99, 120]

# #create lables
# cats_labels = ["-60+", "-40-59", "-20-39", "-19--1", "0-19", "20-39", "40-59", "60+"]


#cut the dataframe
clean_city_data["Lat Summary"] = pd.cut(clean_city_data["Lat"], lats_bin, labels=lats_labels)

#create a groupby dataframe
lat_summary = clean_city_data.groupby("Lat Summary")["Wind Speed"].count().to_frame("Total Count")

# #save the sum to a variable
# age_summary_total = age_summary["Total Count"].sum()

# #create the new column
# age_summary["Percentage of Players"] = age_summary["Total Count"] / age_summary_total

# #format the column
# age_summary["Percentage of Players"] = age_summary["Percentage of Players"].map("{:.2%}".format)

#display the dataframe
lat_summary
# Out:
#              Total Count
# Lat Summary
# -60+                   0
# -40-59                21
# -20-39                98
# -19--1               117
# 0-19                  90
# 20-39                126
# 40-59                146
# 60+                   97

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat = clean_city_data['Lat']
max_temp = clean_city_data['Max Temp']

plt.figure(figsize=(12,8))
plt.scatter(x=lat, y=max_temp, marker="o", facecolors="peachpuff", edgecolors="darkorange", zorder=2)
plt.title(f"Latitude vs Temperature (F)\nAnalysis Date: {curr_date}", weight='bold', size=14)
plt.ylabel("Max Temperature (F)", weight='bold', size=12)
plt.xlabel("Latitude", weight='bold', size=12)
plt.xlim(min(lat)-10, max(lat)+10)
plt.ylim(min(max_temp)-10, max(max_temp)+10)
plt.grid(axis='both', linestyle='--', alpha=.5, zorder=3)

plt.tight_layout()

out_file = os.path.join('..', '..', 'assets', 'images', 'lats_maxtemps.png')
plt.savefig(out_file)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity = clean_city_data['Humidity']

plt.figure(figsize=(12,8))
plt.scatter(x=lat, y=humidity, marker="o", facecolors="thistle", edgecolors="indigo", zorder=2)
plt.title(f"Latitude vs. Humidity (%)\nAnalysis Date: {curr_date}",weight='bold', size=14)
plt.ylabel("Humidity (%)",weight='bold', size=12)
plt.xlabel("Latitude",weight='bold', size=12)
plt.xlim(min(lat)-10, max(lat)+10)
plt.ylim(min(humidity)-10, max(humidity)+10)
plt.grid(axis='both', linestyle='--', alpha=.5, zorder=3)

plt.tight_layout()

out_file = os.path.join('..', '..', 'assets', 'images', 'lats_humidity.png')
plt.savefig(out_file)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cloudiness = clean_city_data['Cloudiness']

plt.figure(figsize=(12,8))
plt.scatter(x=lat, y=cloudiness, marker="o", facecolors="lightcyan", edgecolors="darkcyan", zorder=2)
plt.title(f"Cloudiness (%) vs. Latitude\nAnalysis Date: {curr_date}",weight='bold', size=14)
plt.ylabel("Cloudiness (%)",weight='bold', size=12)
plt.xlabel("Latitude",weight='bold', size=12)
plt.xlim(min(lat)-10, max(lat)+10)
plt.ylim(min(cloudiness)-10, max(cloudiness)+10)
plt.grid(axis='both', linestyle='--', alpha=.5, zorder=3)

plt.tight_layout()

out_file = os.path.join('..', '..', 'assets', 'images', 'lats_cloudiness.png')
plt.savefig(out_file)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
wind_speed = clean_city_data['Wind Speed']

plt.figure(figsize=(12,8))
plt.scatter(x=lat, y=wind_speed, marker="o", facecolors="lightblue", edgecolors="darkblue")
plt.title(f"Wind Speed (mph) vs. Latitude\nAnalysis Date: {curr_date}", weight='bold', size=14)
plt.ylabel("Wind Speed (mph)", weight='bold', size=12)
plt.xlabel("Latitude", weight='bold', size=12)
plt.xlim(min(lat)-10, max(lat)+10)
plt.ylim(min(wind_speed)-5, max(wind_speed)+5)
plt.grid(axis='both', linestyle='--', alpha=.5, zorder=3)

plt.tight_layout()

out_file = os.path.join('..', '..', 'assets', 'images', 'lats_wind_speed.png')
plt.savefig(out_file)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern = clean_city_data.loc[clean_city_data['Lat'] >=0]
southern = clean_city_data.loc[clean_city_data['Lat'] <0]

northern_lats = northern['Lat']
northern_max_temps = northern['Max Temp']

correlation = sts.pearsonr(northern_lats, northern_max_temps)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")

# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(northern_lats, northern_max_temps)

# Calculate the predictions
regression_values = northern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x=northern_lats, y=northern_max_temps, marker="o", facecolors="peachpuff", edgecolors="darkorange")

# Plot the regression line
plt.plot(northern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (5, 40), fontsize=14, color="red")


plt.title(f"Temperature (F) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.xlim(min(northern_lats)-5, max(northern_lats)+5)
plt.ylim(min(northern_max_temps)-5, max(northern_max_temps)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","maxtemps_latitude_lr_north.png"))
# Out:
# The correlation coefficient (r) is -0.817
# The p-value is 1.1059735143024272e-110

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_lats = southern['Lat']
southern_max_temps = southern['Max Temp']

correlation = sts.pearsonr(southern_lats, southern_max_temps)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")

# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(southern_lats, southern_max_temps)

# Calculate the predictions
regression_values = southern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x=southern_lats, y=southern_max_temps, marker="o", facecolors="peachpuff", edgecolors="darkorange")

# Plot the regression line
plt.plot(southern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-40, 80), fontsize=14, color="red")


plt.title(f"Temperature (F) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.xlim(min(southern_lats)-5, max(southern_lats)+5)
plt.ylim(min(southern_max_temps)-5, max(southern_max_temps)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","maxtemps_lats_lr_south.png"))
# Out:
# The correlation coefficient (r) is 0.699
# The p-value is 1.3400898797747413e-30

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
northern_hums = northern['Humidity']

correlation = sts.pearsonr(northern_lats, northern_hums)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")

# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(northern_lats, northern_hums)

# Calculate the predictions
regression_values = northern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x=northern_lats, y=northern_hums, marker="o", facecolors="aquamarine", edgecolors="lightseagreen")

# Plot the regression line
plt.plot(northern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (45, 15), fontsize=14, color="red")


plt.title(f"Humidity (%) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.xlim(min(northern_lats)-5, max(northern_lats)+5)
plt.ylim(min(northern_hums)-5, max(northern_hums)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","humidity_lats_lr_north.png"))
# Out:
# The correlation coefficient (r) is -0.031
# The p-value is 0.5091656849158472

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
southern_hums = southern['Humidity']

correlation = sts.pearsonr(southern_lats, southern_hums)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")

# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(southern_lats, southern_hums)

# Calculate the predictions
regression_values = southern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x=southern_lats, y=southern_hums, marker="o", facecolors="aquamarine", edgecolors="lightseagreen")

# Plot the regression line
plt.plot(southern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 20), fontsize=14, color="red")


plt.title(f"Humidity (%) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.xlim(min(southern_lats)-5, max(southern_lats)+5)
plt.ylim(min(southern_hums)-5, max(southern_hums)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","humidity_lats_lr_south.png"))
# Out:
# The correlation coefficient (r) is 0.14
# The p-value is 0.04874233280947229

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
northern_clouds = northern['Cloudiness']

correlation = sts.pearsonr(northern_lats, northern_clouds)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")

# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(northern_lats, northern_clouds)

# Calculate the predictions
regression_values = northern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x=northern_lats, y=northern_clouds, marker="o", facecolors="lightcyan", edgecolors="darkcyan")

# Plot the regression line
plt.plot(northern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (40, 10), fontsize=14, color="red")


plt.title(f"Cloudiness (%) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.xlim(min(northern_lats)-5, max(northern_lats)+5)
plt.ylim(min(northern_clouds)-5, max(northern_clouds)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","cloudiness_lats_lr_north.png"))
# Out:
# The correlation coefficient (r) is 0.013
# The p-value is 0.774613903775449

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
southern_clouds = southern['Cloudiness']

correlation = sts.pearsonr(southern_lats, southern_clouds)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")


# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(southern_lats, southern_clouds)

# Calculate the predictions
regression_values = southern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x=southern_lats, y=southern_clouds, marker="o", facecolors="lightcyan", edgecolors="darkcyan")

# Plot the regression line
plt.plot(southern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 20), fontsize=14, color="red")


plt.title(f"Cloudiness (%) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.xlim(min(southern_lats)-5, max(southern_lats)+5)
plt.ylim(min(southern_clouds)-5, max(southern_clouds)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","cloudiness_lats_lr_south.png"))
# Out:
# The correlation coefficient (r) is 0.037
# The p-value is 0.5993305188556938

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
northern_wind_speed = northern['Wind Speed']

correlation = sts.pearsonr(northern_lats, northern_wind_speed)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")


# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(northern_lats, northern_wind_speed)

# Calculate the predictions
regression_values = northern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x=northern_lats, y=northern_wind_speed, marker="o", facecolors="lightblue", edgecolors="darkblue")

# Plot the regression line
plt.plot(northern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (20,25), fontsize=14, color="red")


plt.title(f"Wind Speed (mph) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.xlim(min(northern_lats)-5, max(northern_lats)+5)
plt.ylim(min(northern_wind_speed)-5, max(northern_wind_speed)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","windspeed_lats_lr_north.png"))
# Out:
# The correlation coefficient (r) is 0.225
# The p-value is 1.1881299071644244e-06

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
southern_wind_speed = southern['Wind Speed']


correlation = sts.pearsonr(southern_lats, southern_wind_speed)

print(f"The correlation coefficient (r) is {round(correlation[0],3)}")
print(f"The p-value is {correlation[1]}")


# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = sts.linregress(southern_lats, southern_wind_speed)

# Calculate the predictions
regression_values = southern_lats * slope + intercept

# Create a variable for the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x=southern_lats, y=southern_wind_speed, marker="o", facecolors="lightblue", edgecolors="darkblue")

# Plot the regression line
plt.plot(southern_lats, regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50,20), fontsize=14, color="red")


plt.title(f"Wind Speed (mph) vs. Latitude\nAnalysis Date: {curr_date}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.xlim(min(southern_lats)-5, max(southern_lats)+5)
plt.ylim(min(southern_wind_speed)-5, max(southern_wind_speed)+5)
plt.grid(b=None, which='major', axis='both')

plt.savefig(os.path.join("Output","windspeed_lats_lr_south.png"))
# Out:
# The correlation coefficient (r) is -0.339
# The p-value is 8.793179836345461e-07
